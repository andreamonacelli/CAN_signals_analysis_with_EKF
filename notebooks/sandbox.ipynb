# %% [markdown]
# # Sandbox Notebook
# This is a Sandbox Jupyter Notebook whose main goal is to test functions and/or methods without having to launch the whole main script

# %%
import os.path
import pandas as pd
from pyprojroot import here
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
my_path = 'data/recan-C-1-AlfaRomeo-Giulia/Exp-1/unified.tar.gz'
split_path = my_path.split('/')[1].split('-')[0]
print(split_path)

my_path2 = 'data/openlka-Hyundai-Ioniq5/Exp-1/data.csv'
split_path2 = my_path2.split('/')[1].split('-')[0]
print(split_path2)
# Out:
# recan
# openlka

# %%
root_path = here()
folder_path = root_path / 'data/openlka-Hyundai-Ioniq5/Exp-1/'
files_in_path = os.listdir(folder_path)
print(files_in_path)
# Out:
# ['data.csv']

# %%
# TO TEST IF THE OPENLKA DATA IS ACTUALLY IN m/s RATHER THAN IN kph
openlka_file_path = folder_path / 'data.csv'
openlka_df = pd.read_csv(openlka_file_path, sep=';', decimal=',', low_memory=False)
openlka_max_speed_val = openlka_df['vEgo'].astype('float64').min()
print(f'Max speed value for OpenLKA: {openlka_max_speed_val}')
# Out:
# Max speed value for OpenLKA: -0.001220119
