# %% [markdown]
# # Sandbox Notebook
# This is a Sandbox Jupyter Notebook whose main goal is to test functions and/or methods without having to launch the whole main script

# %%
import os.path
# %load_ext autoreload
# %autoreload 2

# %%
split_path = os.path.split('data/C-1-AlfaRomeo-Giulia/Exp-1/unified.tar.gz')[0].replace('data', 'outputs')
print(split_path)

split_path2 = os.path.split('data/CANdid-Holden-Astra/Exp-1/1_driving_CAN.log')[0].replace('data', 'outputs')
print(split_path2)
# Out:
# outputs/C-1-AlfaRomeo-Giulia/Exp-1
# outputs/CANdid-Holden-Astra/Exp-1
